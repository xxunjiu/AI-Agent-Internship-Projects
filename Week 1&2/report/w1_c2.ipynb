# %% [markdown]
# ### 1.Loading  dataset
# #### Chunk by chunk reading
# ##### &emsp;&emsp;chunker = pd.read_csv ('file path', chunksize = n)
# ###### &emsp;&emsp;n=chunk size, rows per block

# %% [markdown]
# ### 2. Header and index modification
# ##### &emsp;&emsp;ie:

# %%
df = pd.read_csv('.../train.csv', 
                 names=['乘客ID','是否幸存','仓位等级','姓名','性别','年龄','兄弟姐妹个数','父母子女个数','船票信息','票价','客舱','登船港口'], 
                 index_col='乘客 ID', 
                 header=0)
df.head()

# %% [markdown]
# ##### Parameters used:
# ###### &emsp;&emsp; names: list used to rename the columns into Chinese
# ###### &emsp;&emsp; index_co1: sets the designed column as the row index tracker
# ###### &emsp;&emsp; header=0: replaces the existing row 0 with the newly passed names list

# %% [markdown]
# #### 3. Data observation
# ##### &emsp;&emsp; 1. Structural summary
# ###### &emsp;&emsp; Syntax:

# %%
df.info()

# %% [markdown]
# ##### &emsp;&emsp; 2. Scanning data subsets
# ###### &emsp;&emsp; Top rows preview:

# %%
df.head()

# %% [markdown]
# ###### &emsp;&emsp; Bottomm rows preview:

# %%
df.tail()

# %% [markdown]
# ##### &emsp;&emsp; 3.Explicit missing value detection
# ###### &emsp;&emsp; Syntax:

# %%
 df.isnull().head()

# %% [markdown]
# ###### &emsp;&emsp; Output: Returns a DataFrame filled with Boolean flags (True if the cell is completely empty/NaN, and False if data exists).

# %% [markdown]
# #### Data exporting and storage
# ##### &emsp;&emsp; Saving data:

# %%
df.to_csv('file path')

# %% [markdown]
# #### 4. Exploratory data analysis
# ##### &emsp;&emsp;1. Multi column sorting
# ###### &emsp;&emsp; Syntax:

# %%
text.sort_values(by=['column1','column2',],ascending = False/True).head()

# %% [markdown]
# ###### &emsp;&emsp;Explanation: Looking at the top 20 passengers who paid the absolute highest ticket fares

# %% [markdown]
# #### 5. Combined column
# ##### ie: To find out the size of single largest family onboard
# ###### &emsp;&emsp; Syntax:

# %%
max(text['兄弟姐妹个数'] + text['父母子女个数'])

# %% [markdown]
# #### 6. Statistical analysis
# ##### &emsp;&emsp; Syntax:

# %%
.describe()

# %% [markdown]
# ###### &emsp;&emsp; The outputs summary statistics for numerical columns, including count, mean, standard deviation (std), min, max, and quartiles
